# %%
#作業重點
#使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

#作業目標:
#請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#lr = [0.1, 0.0001]
#主要驗證 Lr 對於grandient 收斂的速度

# %%
cur_x = 3 # The algorithm starts at x=3
lr = 0.00001 # Learning rate    學習率
precision = 0.000001 #This tells us when to stop the algorithm
previous_step_size = 1 # 開始大小
max_iters = 10000 # maximum number of iterations
iters = 0 #iteration counter 迭代計數器
df = lambda x: 3*(x+5) #Gradient of our function 
iters_history = [iters]
x_history = [cur_x]

# %%
'''
需要執行初始值設定, 下列三個
# Learning rate
#iteration counter
#Step size  
'''
'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''


while previous_step_size > precision and iters < max_iters:
    prev_x = cur_x #Store current x value in prev_x 將當前x值存儲在prev_x中
    cur_x = cur_x - lr * df(prev_x) #Gradient descent 梯度下降
    previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x x的變化
    iters = iters+2 #iteration count 迭代次數
    print("Iteration",iters,"\nX value is",cur_x) #Print iterations
     # Store parameters for plotting 存儲繪圖參數
    iters_history.append(iters)
    x_history.append(cur_x)
    #所謂的While迴圈。使用While迴圈的機會不如For迴圈那麼多，但是在某些情況下，還是需要它才能夠完成工作
# Out:
# Iteration 2
# X value is 2.99976
# Iteration 4
# X value is 2.9995200072
# Iteration 6
# X value is 2.999280021599784
# Iteration 8
# X value is 2.9990400431991358
# Iteration 10
# X value is 2.99880007199784
# Iteration 12
# X value is 2.99856010799568
# Iteration 14
# X value is 2.99832015119244
# Iteration 16
# X value is 2.998080201587904
# Iteration 18
# X value is 2.9978402591818565
# Iteration 20
# X value is 2.997600323974081
# Iteration 22
# X value is 2.9973603959643618
# Iteration 24
# X value is 2.997120475152483
# Iteration 26
# X value is 2.9968805615382283
# Iteration 28
# X value is 2.9966406551213822
# Iteration 30
# X value is 2.9964007559017287
# Iteration 32
# X value is 2.9961608638790516
# Iteration 34
# X value is 2.9959209790531354
# Iteration 36
# X value is 2.995681101423764
# Iteration 38
# X value is 2.9954412309907212
# Iteration 40
# X value is 2.9952013677537916
# Iteration 42
# X value is 2.994961511712759
# Iteration 44
# ...

# %%
print("Totally iteations: ", iters)
print("The local minimum occurs at", cur_x)
# Out:
# Totally iteations:  10000
# The local minimum occurs at 1.8856483183644648

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
#適用於 Jupyter Notebook, 宣告直接在cell 內印出執行結果

plt.plot(iters_history, x_history, 'o-', ms=3, lw=1.5, color='black')
plt.xlabel(r'$iters$', fontsize=16)
plt.ylabel(r'$x$', fontsize=16)
plt.show()
